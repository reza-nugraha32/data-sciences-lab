# %% [markdown]
# # Apple Quality Classification
#
# In this notebook we will build a binary classification model from the apple quality dataset from Kaggle using Tensorflow. We hope to construct a model that will predict an apple as 'good' or 'bad' depending on its inputs.
# First we will investigate the dataset to perform an exploratory data analysis.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import sklearn
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv('apple_quality.csv')
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %% [markdown]
# There are 4000 rows of data with 9 columns, 'A_id' for unique IDs, 'Quality' for 'good' or 'bad' apples, while the rest is numerical columns including 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness', 'Ripeness', and 'Acidity'.
#
# ## Check for missing and duplicated values

# %%
# Check data description
df.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
# Check for missing values
df.isnull().any()
# Out:
# A_id            True
# Size            True
# Weight          True
# Sweetness       True
# Crunchiness     True
# Juiciness       True
# Ripeness        True
# Acidity        False
# Quality         True
# dtype: bool

# %% [markdown]
# We have missing values in the 4000th row. Let's check and handle that!

# %%
# Check the missing value index
np.where(df.isnull())[0]
# Out:
# array([4000, 4000, 4000, 4000, 4000, 4000, 4000, 4000], dtype=int64)

# %%
# Drop the last row
df.drop(df.tail(1).index, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %% [markdown]
# ## Build classification model
#
# As we noticed before, we have a binary column and a bunch of numerical columns. We want to encode the binary column to be our target column, and the rest 7 columns as our numerical columns which will be the input parameters for our prediction. We would also drop our ID column since we don't need that.

# %%
# Encode target column to 'good': 1 and 'bad': 0
target_column = 'Quality'
df[target_column] = df[target_column].map({'good': 1, 'bad': 0})

# Drop target column
output_rows = df[target_column]
numerical_column = df.columns.drop(target_column)
df.drop(target_column, axis=1, inplace=True)
df.drop('A_id', axis=1, inplace=True)

# %% [markdown]
# We would to normalize our data using Min-Max scaler to build our classification model. Then, we would split our train-test data, and train our model.

# %%
scaler = MinMaxScaler()
scaler.fit(df)
t_df = scaler.transform(df)

X_train, X_test, y_train, y_test = train_test_split(t_df, output_rows, test_size=0.25, random_state=0)

# Model with a dense layer with 64 neurons and 7 input from the parameters
model = keras.models.Sequential([
    keras.layers.Dense(units=64, activation='relu', input_shape=(7,)),
    keras.layers.Dense(1, activation='sigmoid')
])

adam = keras.optimizers.Adam(learning_rate=0.005)

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=["accuracy"])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 0s 991us/step - loss: 0.6518 - accuracy: 0.6487
# Epoch 2/100
# 94/94 [==============================] - 0s 911us/step - loss: 0.5788 - accuracy: 0.7073
# Epoch 3/100
# 94/94 [==============================] - 0s 944us/step - loss: 0.5329 - accuracy: 0.7360
# Epoch 4/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.5075 - accuracy: 0.7527
# Epoch 5/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.4824 - accuracy: 0.7703
# Epoch 6/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.4616 - accuracy: 0.7813
# Epoch 7/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.4439 - accuracy: 0.7940
# Epoch 8/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.8090
# Epoch 9/100
# 94/94 [==============================] - 0s 957us/step - loss: 0.4097 - accuracy: 0.8190
# Epoch 10/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8223
# Epoch 11/100
# 94/94 [==============================] - 0s 879us/step - loss: 0.3771 - accuracy: 0.8333
# Epoch 12/100
# 94/94 [==============================] - 0s 926us/step - loss: 0.3735 - accuracy: 0.8320
# Epoch 13/100
# 94/94 [==============================] - 0s 917us/step - loss: 0.3630 - accuracy: 0.8407
# Epoch 14/100
# 94/94 [==============================] - 0s 903us/step - loss: 0.3570 - accuracy: 0.8407
# Epoch 15/100
# 94/94 [==============================] - 0s 912us/step - loss: 0.3480 - accuracy: 0.8423
# Epoch 16/100
# 94/94 [==============================] - 0s 903us/step - loss: 0.3432 - accuracy: 0.8437
# Epoch 17/100
# 94/94 [==============================] - 0s 926us/step - loss: 0.3343 - accuracy: 0.8460
# Epoch 18/100
# 94/94 [==============================] - 0s 989us/step - loss: 0.3356 - accuracy: 0.8470
# Epoch 19/100
# 94/94 [==============================] - 0s 903us/step - loss: 0.3252 - accuracy: 0.8547
# Epoch 20/100
# 94/94 [==============================] - 0s 933us/step - loss: 0.3260 - accuracy: 0.8560
# Epoch 21/100
# 94/94 [==============================] - 0s 924us/step - loss: 0.3302 - accuracy: 0.8557
# Epoch 22/100
# 94/94 [==============================] - 0s 905us/step - loss: 0.3186 - accuracy: 0.8547
# Epoch 23/100
# 94/94 [==============================] - 0s 918us/step - loss: 0.3180 - accuracy: 0.8540
# Epoch 24/100
# 94/94 [==============================] - 0s 938us/step - loss: 0.3112 - accuracy: 0.8603
# Epoch 25/100
# 94/94 [==============================] - 0s 910us/step - loss: 0.3072 - accuracy: 0.8597
# Epoch 26/100
# 94/94 [==============================] - 0s 935us/step - loss: 0.3058 - accuracy: 0.8583
# Epoch 27/100
# 94/94 [==============================] - 0s 910us/step - loss: 0.3042 - accuracy: 0.8630
# Epoch 28/100
# 94/94 [==============================] - 0s 906us/step - loss: 0.3033 - accuracy: 0.8637
# Epoch 29/100
# 94/94 [==============================] - 0s 941us/step - loss: 0.3080 - accuracy: 0.8610
# Epoch 30/100
# 94/94 [==============================] - 0s 940us/step - loss: 0.3005 - accuracy: 0.8683
# Epoch 31/100
# 94/94 [==============================] - 0s 906us/step - loss: 0.2950 - accuracy: 0.8700
# Epoch 32/100
# 94/94 [==============================] - 0s 928us/step - loss: 0.2987 - accuracy: 0.8630
# Epoch 33/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.3005 - accuracy: 0.8670
# Epoch 34/100
# 94/94 [==============================] - 0s 960us/step - loss: 0.2981 - accuracy: 0.8670
# Epoch 35/100
# 94/94 [==============================] - 0s 949us/step - loss: 0.3006 - accuracy: 0.8637
# Epoch 36/100
# 94/94 [==============================] - 0s 985us/step - loss: 0.2985 - accuracy: 0.8660
# Epoch 37/100
# 94/94 [==============================] - 0s 967us/step - loss: 0.2937 - accuracy: 0.8703
# Epoch 38/100
# 94/94 [==============================] - 0s 928us/step - loss: 0.2924 - accuracy: 0.8667
# Epoch 39/100
# 94/94 [==============================] - 0s 930us/step - loss: 0.2911 - accuracy: 0.8693
# Epoch 40/100
# 94/94 [==============================] - 0s 957us/step - loss: 0.2923 - accuracy: 0.8653
# Epoch 41/100
# 94/94 [==============================] - 0s 936us/step - loss: 0.2895 - accuracy: 0.8737
# Epoch 42/100
# 94/94 [==============================] - 0s 916us/step - loss: 0.2896 - accuracy: 0.8733
# Epoch 43/100
# 94/94 [==============================] - 0s 942us/step - loss: 0.2867 - accuracy: 0.8747
# Epoch 44/100
# 94/94 [==============================] - 0s 935us/step - loss: 0.2817 - accuracy: 0.8757
# Epoch 45/100
# 94/94 [==============================] - 0s 913us/step - loss: 0.2907 - accuracy: 0.8700
# Epoch 46/100
# 94/94 [==============================] - 0s 945us/step - loss: 0.2937 - accuracy: 0.8717
# Epoch 47/100
# 94/94 [==============================] - 0s 914us/step - loss: 0.2822 - accuracy: 0.8740
# Epoch 48/100
# 94/94 [==============================] - 0s 922us/step - loss: 0.2862 - accuracy: 0.8697
# Epoch 49/100
# 94/94 [==============================] - 0s 943us/step - loss: 0.2810 - accuracy: 0.8767
# Epoch 50/100
# 94/94 [==============================] - 0s 925us/step - loss: 0.2845 - accuracy: 0.8740
# Epoch 51/100
# 94/94 [==============================] - 0s 951us/step - loss: 0.2808 - accuracy: 0.8740
# Epoch 52/100
# 94/94 [==============================] - 0s 913us/step - loss: 0.2811 - accuracy: 0.8737
# Epoch 53/100
# 94/94 [==============================] - 0s 944us/step - loss: 0.2795 - accuracy: 0.8787
# Epoch 54/100
# 94/94 [==============================] - 0s 931us/step - loss: 0.2786 - accuracy: 0.8760
# Epoch 55/100
# 94/94 [==============================] - 0s 911us/step - loss: 0.2801 - accuracy: 0.8743
# Epoch 56/100
# 94/94 [==============================] - 0s 954us/step - loss: 0.2804 - accuracy: 0.8753
# Epoch 57/100
# 94/94 [==============================] - 0s 945us/step - loss: 0.2804 - accuracy: 0.8670
# Epoch 58/100
# 94/94 [==============================] - 0s 922us/step - loss: 0.2778 - accuracy: 0.8770
# Epoch 59/100
# 94/94 [==============================] - 0s 938us/step - loss: 0.2837 - accuracy: 0.8717
# Epoch 60/100
# 94/94 [==============================] - 0s 914us/step - loss: 0.2740 - accuracy: 0.8780
# Epoch 61/100
# 94/94 [==============================] - 0s 939us/step - loss: 0.2786 - accuracy: 0.8767
# Epoch 62/100
# 94/94 [==============================] - 0s 931us/step - loss: 0.2754 - accuracy: 0.8787
# Epoch 63/100
# 94/94 [==============================] - 0s 952us/step - loss: 0.2755 - accuracy: 0.8757
# Epoch 64/100
# 94/94 [==============================] - 0s 911us/step - loss: 0.2781 - accuracy: 0.8773
# Epoch 65/100
# 94/94 [==============================] - 0s 937us/step - loss: 0.2733 - accuracy: 0.8790
# Epoch 66/100
# 94/94 [==============================] - 0s 908us/step - loss: 0.2758 - accuracy: 0.8787
# Epoch 67/100
# 94/94 [==============================] - 0s 962us/step - loss: 0.2746 - accuracy: 0.8790
# Epoch 68/100
# 94/94 [==============================] - 0s 923us/step - loss: 0.2751 - accuracy: 0.8780
# Epoch 69/100
# 94/94 [==============================] - 0s 934us/step - loss: 0.2691 - accuracy: 0.8813
# Epoch 70/100
# 94/94 [==============================] - 0s 957us/step - loss: 0.2755 - accuracy: 0.8717
# Epoch 71/100
# 94/94 [==============================] - 0s 983us/step - loss: 0.2704 - accuracy: 0.8803
# Epoch 72/100
# 94/94 [==============================] - 0s 928us/step - loss: 0.2696 - accuracy: 0.8770
# Epoch 73/100
# 94/94 [==============================] - 0s 935us/step - loss: 0.2690 - accuracy: 0.8723
# Epoch 74/100
# 94/94 [==============================] - 0s 920us/step - loss: 0.2701 - accuracy: 0.8750
# Epoch 75/100
# 94/94 [==============================] - 0s 977us/step - loss: 0.2710 - accuracy: 0.8830
# Epoch 76/100
# 94/94 [==============================] - 0s 902us/step - loss: 0.2700 - accuracy: 0.8787
# Epoch 77/100
# 94/94 [==============================] - 0s 990us/step - loss: 0.2706 - accuracy: 0.8777
# Epoch 78/100
# 94/94 [==============================] - 0s 991us/step - loss: 0.2721 - accuracy: 0.8790
# Epoch 79/100
# 94/94 [==============================] - 0s 1ms/step - loss: 0.2738 - accuracy: 0.8790
# Epoch 80/100
# 94/94 [==============================] - 0s 981us/step - loss: 0.2688 - accuracy: 0.8857
# Epoch 81/100
# 94/94 [==============================] - 0s 954us/step - loss: 0.2708 - accuracy: 0.8827
# Epoch 82/100
# 94/94 [==============================] - 0s 950us/step - loss: 0.2690 - accuracy: 0.8833
# Epoch 83/100
# 94/94 [==============================] - 0s 975us/step - loss: 0.2677 - accuracy: 0.8770
# Epoch 84/100
# 94/94 [==============================] - 0s 997us/step - loss: 0.2643 - accuracy: 0.8843
# Epoch 85/100
# 94/94 [==============================] - 0s 964us/step - loss: 0.2659 - accuracy: 0.8783
# Epoch 86/100
# 94/94 [==============================] - 0s 964us/step - loss: 0.2665 - accuracy: 0.8803
# Epoch 87/100
# 94/94 [==============================] - 0s 975us/step - loss: 0.2651 - accuracy: 0.8833
# Epoch 88/100
# 94/94 [==============================] - 0s 933us/step - loss: 0.2627 - accuracy: 0.8797
# Epoch 89/100
# 94/94 [==============================] - 0s 929us/step - loss: 0.2642 - accuracy: 0.8827
# Epoch 90/100
# 94/94 [==============================] - 0s 942us/step - loss: 0.2650 - accuracy: 0.8810
# Epoch 91/100
# 94/94 [==============================] - 0s 948us/step - loss: 0.2655 - accuracy: 0.8817
# Epoch 92/100
# 94/94 [==============================] - 0s 956us/step - loss: 0.2720 - accuracy: 0.8760
# Epoch 93/100
# 94/94 [==============================] - 0s 927us/step - loss: 0.2775 - accuracy: 0.8733
# Epoch 94/100
# 94/94 [==============================] - 0s 939us/step - loss: 0.2653 - accuracy: 0.8860
# Epoch 95/100
# 94/94 [==============================] - 0s 967us/step - loss: 0.2627 - accuracy: 0.8843
# Epoch 96/100
# 94/94 [==============================] - 0s 962us/step - loss: 0.2626 - accuracy: 0.8803
# Epoch 97/100
# 94/94 [==============================] - 0s 946us/step - loss: 0.2671 - accuracy: 0.8850
# Epoch 98/100
# 94/94 [==============================] - 0s 934us/step - loss: 0.2621 - accuracy: 0.8847
# Epoch 99/100
# 94/94 [==============================] - 0s 929us/step - loss: 0.2631 - accuracy: 0.8847
# Epoch 100/100
# 94/94 [==============================] - 0s 942us/step - loss: 0.2591 - accuracy: 0.8890
