# %% [markdown]
# <a href="https://colab.research.google.com/github/reza-nugraha32/data-sciences-lab/blob/main/data_cleansing_case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Read dataset uncleaned_raw.csv
uncleaned_raw = pd.read_csv('https://storage.googleapis.com/dqlab-dataset/uncleaned_raw.csv')

# Check for outlier
uncleaned_raw.boxplot()
plt.show()

# Check for IQR
Q1 = uncleaned_raw['UnitPrice'].quantile(0.25)
Q3 = uncleaned_raw['UnitPrice'].quantile(0.75)
IQR = Q3 - Q1

# Removing outliers
uncleaned_raw = uncleaned_raw[~((uncleaned_raw['UnitPrice'] < (Q1 - 1.5*IQR)) | (uncleaned_raw['UnitPrice'] > (Q3 + 1.5*IQR)))]
uncleaned_raw.boxplot()
plt.show()

# Check for duplicates
print(uncleaned_raw.duplicated(subset=None))

# Remove duplicates
uncleaned_raw = uncleaned_raw.drop_duplicates()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# Length: 502, dtype: bool
