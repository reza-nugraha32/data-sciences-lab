# %% [markdown]
# <a href="https://colab.research.google.com/github/reza-nugraha32/data-sciences-lab/blob/main/seleksi-dsa-compfest15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

data_rekap_2015 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2015.csv")
data_rekap_2016 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2016.csv")
data_rekap_2017 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2017.csv")
data_rekap_2018 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2018.csv")
data_rekap_2019 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2019.csv")
data_rekap_2020 = pd.read_csv("https://raw.githubusercontent.com/reza-nugraha32/data-sciences-lab/main/dataset-compfest/data-rekapitulasi-kejadian-banjir-tahun-2020.csv")

# %%
data_rekap_2015.head(10)
# Out:
#    bulan  kecamatan  kelurahan rata_rata_ketinggian_air  lama_genangan  \
# 0      1         15         36                10 - 150               2
# 1      2         38        133                10 - 200               7
# 2      3         12         15                10 - 200               4
# 3      4          4          6                20 - 100               3
# 4      5          1          1                20 - 100               1
# 5      6          0          0                        0              0
# 6      7          0          0                        0              0
# 7      8          0          0                        0              0
# 8      9          0          0                        0              0
# 9     10          0          0                        0              0
#
#    rw_terdampak  kk_terdampak  jiwa_terdampak  korban_meninggal  \
# 0           221          6095           13073                 0
# ...

# %%
# Append data rekap 5 tahun terakhir
data_rekap = data_rekap_2015

data_rekap.head(20)
# Out:
#     bulan  kecamatan  kelurahan rata_rata_ketinggian_air  lama_genangan  \
# 0       1         15         36                10 - 150               2
# 1       2         38        133                10 - 200               7
# 2       3         12         15                10 - 200               4
# 3       4          4          6                20 - 100               3
# 4       5          1          1                20 - 100               1
# 5       6          0          0                        0              0
# 6       7          0          0                        0              0
# 7       8          0          0                        0              0
# 8       9          0          0                        0              0
# 9      10          0          0                        0              0
# 10     11          7         11                20 - 300               4
# 11     12         12         15                  10 - 60              4
#
# ...

# %%
data_rekap_2015.hist(group)
# Out:
# array([[<Axes: title={'center': 'bulan'}>,
#         <Axes: title={'center': 'kecamatan'}>,
#         <Axes: title={'center': 'kelurahan'}>,
#         <Axes: title={'center': 'lama_genangan'}>],
#        [<Axes: title={'center': 'rw_terdampak'}>,
#         <Axes: title={'center': 'kk_terdampak'}>,
#         <Axes: title={'center': 'jiwa_terdampak'}>,
#         <Axes: title={'center': 'korban_meninggal'}>],
#        [<Axes: title={'center': 'korban_hilang'}>,
#         <Axes: title={'center': 'korban_luka_berat'}>,
#         <Axes: title={'center': 'korban_luka_ringan'}>,
#         <Axes: title={'center': 'jumlah_jiwa_pengungsi_tertinggi'}>],
#        [<Axes: title={'center': 'jumlah_tempat_pengungsian'}>,
#         <Axes: title={'center': 'jumlah_nilai_kerugian'}>, <Axes: >,
#         <Axes: >]], dtype=object)
